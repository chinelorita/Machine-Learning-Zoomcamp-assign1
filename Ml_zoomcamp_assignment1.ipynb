# %%
import numpy as np
import pandas as pd
np.__version__
# Out:
# '1.20.1'

# %%
#read file
df = pd.read_csv("C:\\Users\\lenovo\\Documents\\mlzoomcamp1.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
#To check most popular car manufacturers
df["Make"].value_counts()
# Out:
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
#Number of unique Audi car model
df_audi = df[df["Make"]== "Audi"]
df_audi["Model"].nunique()
# Out:
# 34

# %%
#To visualize columns with missing values
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df["Engine Cylinders"].describe()
# Out:
# count    11884.000000
# mean         5.628829
# std          1.780559
# min          0.000000
# 25%          4.000000
# 50%          6.000000
# 75%          6.000000
# max         16.000000
# Name: Engine Cylinders, dtype: float64

# %%
#does the value of median chnage after filling missing values
df["Engine Cylinders"].fillna(4.0)
df["Engine Cylinders"].median()
# Out:
# 6.0

# %%
df_lotus = df[df["Make"]== "Lotus"]
df[["Engine HP", "Engine Cylinders"]].drop_duplicates()
# Out:
#        Engine HP  Engine Cylinders
# 0          335.0               6.0
# 1          300.0               6.0
# 3          230.0               6.0
# 15         320.0               6.0
# 17         172.0               6.0
# ...          ...               ...
# 11640      197.0               5.0
# 11768      410.0               6.0
# 11792       97.0               4.0
# 11885      184.0               6.0
# 11903      394.0               8.0
#
# [572 rows x 2 columns]

# %%
n = np.array(df_lotus)
n
# Out:
# array([['Lotus', 'Elise', 2009, 'premium unleaded (required)', 189.0,
#         4.0, 'MANUAL', 'rear wheel drive', 2.0,
#         'Exotic,High-Performance', 'Compact', 'Convertible', 27, 21, 613,
#         43995],
#        ['Lotus', 'Elise', 2009, 'premium unleaded (required)', 218.0,
#         4.0, 'MANUAL', 'rear wheel drive', 2.0,
#         'Exotic,High-Performance', 'Compact', 'Convertible', 26, 20, 613,
#         54990],
#        ['Lotus', 'Elise', 2009, 'premium unleaded (required)', 189.0,
#         4.0, 'MANUAL', 'rear wheel drive', 2.0,
#         'Exotic,High-Performance', 'Compact', 'Convertible', 27, 21, 613,
#         47250],
#        ['Lotus', 'Elise', 2010, 'premium unleaded (required)', 189.0,
#         4.0, 'MANUAL', 'rear wheel drive', 2.0,
#         'Exotic,High-Performance', 'Compact', 'Convertible', 27, 21, 613,
#         47250],
#        ['Lotus', 'Elise', 2010, 'premium unleaded (required)', 218.0,
#         4.0, 'MANUAL', 'rear wheel drive', 2.0,
# ...

# %%
df.to_dict(orient = "records")
# Out:
# [{'Make': 'BMW',
#   'Model': '1 Series M',
#   'Year': 2011,
#   'Engine Fuel Type': 'premium unleaded (required)',
#   'Engine HP': 335.0,
#   'Engine Cylinders': 6.0,
#   'Transmission Type': 'MANUAL',
#   'Driven_Wheels': 'rear wheel drive',
#   'Number of Doors': 2.0,
#   'Market Category': 'Factory Tuner,Luxury,High-Performance',
#   'Vehicle Size': 'Compact',
#   'Vehicle Style': 'Coupe',
#   'highway MPG': 26,
#   'city mpg': 19,
#   'Popularity': 3916,
#   'MSRP': 46135},
#  {'Make': 'BMW',
#   'Model': '1 Series',
#   'Year': 2011,
#   'Engine Fuel Type': 'premium unleaded (required)',
#   'Engine HP': 300.0,
#   'Engine Cylinders': 6.0,
#   'Transmission Type': 'MANUAL',
#   'Driven_Wheels': 'rear wheel drive',
#   'Number of Doors': 2.0,
#   'Market Category': 'Luxury,Performance',
#   'Vehicle Size': 'Compact',
#   'Vehicle Style': 'Convertible',
#   'highway MPG': 28,
#   'city mpg': 19,
#   'Popularity': 3916,
#   'MSRP': 40650},
#  {'Make': 'BMW',
# ...
